# %% [markdown]
# Predicting the Missing Values using Linear regression

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')
df.drop(df.columns[0], axis=1, inplace=True)
df.head(5)
# Out:
#   Country Name  Year  ...  GDP_Millions  %_expenditure_gdp
# 0    Australia  2010  ...  1.146138e+12            5.55006
# 1      Austria  2010  ...  3.918927e+11            5.70048
# 2   Azerbaijan  2010  ...  5.290929e+10            2.78062
# 3      Belgium  2010  ...  4.809516e+11            6.44259
# 4     Bulgaria  2010  ...  5.038183e+10            3.88239
#
# [5 rows x 9 columns]

# %% [markdown]
# Creating a dataframe for a specific country to perform linear regression.

# %%
df_c = df[df['Country Name']=='Kuwait']
df_c.groupby('Country Name')
col_name = 'MastersAttainment' #change and implement for every educational attainment level column
d= df_c[df_c[col_name].notnull()]
x= d['Year']
y= d[col_name]

# creating a linear regression model

# comment or uncomment the following 2 lines incase of a type error
x1 = x.to_numpy()
y1 = y.to_numpy()

# value of length depends on the number of non null values in a particular column of a country
length = 4

x= x1.reshape(length, 1)
y = y1.reshape(length, 1)

model = linear_model.LinearRegression()
model.fit(x,y)

# predicting the missing values
p = model.predict([[2010],[2011],[2014],[2016],[2012],[2019]]) #change according to the missing values in the main google sheet
p
# Out:
# array([[0.36431253],
#        [0.37453948],
#        [0.40522033],
#        [0.42567423],
#        [0.38476643],
#        [0.45635509]])

# %% [markdown]
# We then plot the data

# %%
#plotting the data
plt.scatter(x, y,  color='black')
plt.plot(x, model.predict(x), color='red', linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# ###We have predicted the values of most of the missing data using Linear regression as the data seemed to follow a general linear trend. This was the only way of handling the missing data where the story of the data was preserved.
